# %%
import numpy as np
import pandas as pd
from scipy import integrate
import matplotlib.pyplot as plt
from main import ODE_error, hillclimber, sim_an, gen_al
import warnings
import time
warnings.filterwarnings('ignore')

df = pd.read_csv('predator-prey-data.csv')
t = df.loc[:,'t'].to_numpy()
data = np.transpose(np.array([df.loc[:,'x'].values.tolist(),df.loc[:,'y'].values.tolist()]))
# Out:
# Start

# %%
plt.plot(np.arange(n_iter),SA_list,label='SA regular')
plt.plot(np.arange(n_iter),SAexp_list)
plt.plot(np.arange(n_iter),HC_list)
plt.legend()

# %%
plt.plot(np.arange(5000),RMSE_conv,label='start1')
plt.plot(np.arange(5000),RMSE_conv2)
plt.legend()

# %%
mean_125 = 0.48108572510892345

# %%
step = 1,50
print(np.std(RMSE_all[0:10]))
print(np.std(RMSE_all[0:15]))
print(np.std(RMSE_all))
print(np.mean(RMSE_all[0:10]))
print(np.mean(RMSE_all[0:15]))
print(np.mean(RMSE_all))
# Out:
# 0.14771850594872898
# 0.16110508483778083
# 0.14714115810314107
# 0.48327965632678005
# 0.4668229318839344
# 0.4932094929768061

# %%
#starting params with step 1,25
print(np.mean(RMSE_all))
print(np.mean(RMSE_all2))
print(np.std(RMSE_all))
print(np.std(RMSE_all2))
# Out:
# 0.5288806368180657
# 0.43189086676089533
# 0.2043908705801887
# 0.09326380345708662

# %%
np.std(RMSE_all2)
# Out:
# 0.5563289110939931

# %%
a = [1,2,3]
b = np.zeros(3).tolist()
a.extend(b)
a
# Out:
# [1, 2, 3, 0.0, 0.0, 0.0]

# %%
point25 = np.array([np.repeat(RMSE_conv2[i+1],50) for i in np.arange(0,len(RMSE_conv2)-1)]).reshape(n_iter)
point50 = np.array([np.repeat(RMSE_conv[i+1],50) for i in np.arange(0,len(RMSE_conv)-1)]).reshape(n_iter)

# tijdelijk = np.array([np.repeat(RMSE_conv[i+1],50) for i in np.arange(0,len(RMSE_conv)-1)]).reshape(n_iter)

plt.plot(np.arange(n_iter),point50,label='point50')
plt.plot(np.arange(n_iter),point25,label='point25')

plt.legend()

# %%
np.random.seed(5)
n_iter = 20000
reps = 10
SA = []
HC = []
HC_conv = np.zeros(n_iter)
SA_conv = np.zeros(n_iter)
start = time.time()
for i in range(reps):
    print(i)
    RMSE, params, RMSE_list = sim_an(ODE_error, data, t,n_iter=n_iter,stepsize=0.25,evalfunc='RMSE')
    SA.append(RMSE)
    SA_conv = [x + y  for x, y in zip(SA_conv, np.array(RMSE_list)/reps)]
    if i == 0: params_SA = params
    elif RMSE < SA[i-1]: params_SA = params
    print(time.time()-start)
    RMSE, params, RMSE_list = hillclimber(ODE_error, data, t,n_iter=n_iter,stepsize=1,evalfunc='RMSE')
    HC.append(RMSE)
    HC_conv = [x + y  for x, y in zip(HC_conv, np.array(RMSE_list)/reps)]
    if i == 0: params_HC = params
    elif RMSE < HC[i-1]: params_HC = params
    print(time.time()-start)
# Out:
# 0
# 144.39869785308838
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-442-52bd13016efe> in <module>
#      15     elif RMSE < SA[i-1]: params_SA = params
#      16     print(time.time()-start)
# ---> 17     RMSE, params, RMSE_list = hillclimber(ODE_error, data, t,n_iter=n_iter,stepsize=1,evalfunc='RMSE')
#      18     HC.append(RMSE)
#      19     HC_conv = [x + y  for x, y in zip(HC_conv, np.array(RMSE_list)/reps)]
#
# ~/Documents/GitHub/stochastic-simulation/Assignment 3/main.py in hillclimber(function, data, t, params0, evalfunc, n_iter, stepsize)
#      50         new_params[new_params > 10] = 10
#      51
# ---> 52         try: new_eval  = function(new_params,data,t,evalfunc)
#      53         except ValueError: new_eval = 100
#      54         if new_eval <= est_eval:
#
# ...

# %%
HC_data = pd.read_csv('Data/Archive/25reps/HC-fulldata-overall-MAE.csv',index_col=0)
SA_data = pd.read_csv('Data/Archive/25reps/SA-fulldata-overall-MAE.csv',index_col=0)
print('HC: mean = {} and std = {}'.format(np.mean(HC_data['HC']),np.std(HC_data['HC'])))
print('HC1: mean = {} and std = {}'.format(np.mean(HC_data['HC1']),np.std(HC_data['HC1'])))
print('HC2: mean = {} and std = {}'.format(np.mean(HC_data['HC2']),np.std(HC_data['HC2'])))
print('SA: mean = {} and std = {}'.format(np.mean(SA_data['SA']),np.std(SA_data['SA'])))
print('SAlin: mean = {} and std = {}'.format(np.mean(SA_data['SAlin']),np.std(SA_data['SAlin'])))
print('SAexp: mean = {} and std = {}'.format(np.mean(SA_data['SAexp']),np.std(SA_data['SAexp'])))
print('SA1: mean = {} and std = {}'.format(np.mean(SA_data['SA1']),np.std(SA_data['SA1'])))
print('SA2: mean = {} and std = {}'.format(np.mean(SA_data['SA2']),np.std(SA_data['SA2'])))

SA_stepsize = pd.read_csv('Data/SA-stepsizeMClen-MAE.csv',index_col=0)
HC_stepsize = pd.read_csv('Data/HC-stepsize-MAE.csv',index_col=0)

print(np.mean(SA_stepsize))
print(np.mean(HC_stepsize))
print(np.std(SA_stepsize))
print(np.std(HC_stepsize))
# Out:
# HC: mean = 1.1570258478469173 and std = 0.6979201212342766
# HC1: mean = 0.2265942935016928 and std = 0.050273477466118495
# HC2: mean = 0.23672192455044783 and std = 0.07045270846333641
# SA: mean = 0.9059515630761555 and std = 0.5483533871711053
# SAlin: mean = 1.5025883797988713 and std = 0.42219496280427965
# SAexp: mean = 1.044543309822674 and std = 0.5339067206698764
# SA1: mean = 0.6975060934478455 and std = 0.45905239080483135
# SA2: mean = 1.2847753219155684 and std = 0.5647139506695932
# SAlow         0.581983
# SAhigh        0.997278
# SAlowloop     0.982449
# SAhighloop    1.180233
# dtype: float64
# HClow     1.606419
# HChigh    0.575721
# dtype: float64
# SAlow         0.670221
# SAhigh        0.425022
# SAlowloop     0.569169
# SAhighloop    0.594147
# dtype: float64
# HClow     0.281200
# HChigh    0.502812
# dtype: float64

# %%
RMSE_data.columns
# Out:
# Index(['HC05', 'HC10', 'HC125', 'HC15', 'HC_start1', 'HC_start2', 'SA01',
#        'SA025', 'SA05', 'SA10', 'SA40', 'SA100', 'SA_exp', 'SA_lin',
#        'SA_init10', 'SA_init01'],
#       dtype='object')

# %%
RMSE_data = pd.read_csv('Data/Usable/optimal-MAE-conv.csv',index_col=0)
plt.plot(np.arange(20000),RMSE_data['HC'],label='HC')
plt.plot(np.arange(20000),RMSE_data['SA'],label='SA')
plt.legend()

# %%
RMSE_data = pd.read_csv('Data/RMSE-conv.csv',index_col=0)
MAE_data = pd.read_csv('Data/MAE-conv.csv',index_col=0)

plt.figure(figsize=(15,10))
plt.plot(np.arange(5000),RMSE_data['HC10'],label='HC10')
plt.plot(np.arange(5000),RMSE_data['HC125'],label='HC125')
plt.plot(np.arange(5000),RMSE_data['SA025'],label='SA025')
plt.plot(np.arange(5000),RMSE_data['SA40'],label='SA40')
plt.plot(np.arange(5000),RMSE_data['SA100'],label='SA100')
plt.plot(np.arange(5000),RMSE_data['SA_exp'],label='SA exp')
plt.plot(np.arange(5000),RMSE_data['SA_lin'],label='SA lin')
plt.plot(np.arange(5000),RMSE_data['SA_init10'],label='SA temp 10')
plt.plot(np.arange(5000),RMSE_data['SA_init01'],label='SA temp 0.1')
plt.legend()
plt.show()

plt.figure(figsize=(15,10))
plt.plot(np.arange(5000),MAE_data['HC10'],label='HC10')
plt.plot(np.arange(5000),MAE_data['HC125'],label='HC125')
plt.plot(np.arange(5000),MAE_data['SA025'],label='SA025')
plt.plot(np.arange(5000),MAE_data['SA40'],label='SA40')
plt.plot(np.arange(5000),MAE_data['SA100'],label='SA100')
plt.plot(np.arange(5000),MAE_data['SA_exp'],label='SA exp')
plt.plot(np.arange(5000),MAE_data['SA_lin'],label='SA lin')
plt.plot(np.arange(5000),MAE_data['SA_init10'],label='SA temp 10')
plt.plot(np.arange(5000),MAE_data['SA_init01'],label='SA temp 0.1')
plt.legend()
plt.show()

# %%
HC_data = pd.read_csv('Data/Archive/25reps/HC-fulldata-avg-conv-RMSE.csv',index_col=0)
SA_data = pd.read_csv('Data/Archive/25reps/SA-fulldata-avg-conv-RMSE.csv',index_col=0)
SA_list = np.array([np.repeat(SA_data['SA'][i+1],50) for i in np.arange(0,len(SA_data)-1)]).reshape(5000)

SA_linlist = np.array([np.repeat(SA_data['SAlin'][i+1],50) for i in np.arange(0,len(SA_data)-1)]).reshape(5000)
SA_explist = np.array([np.repeat(SA_data['SAexp'][i+1],50) for i in np.arange(0,len(SA_data)-1)]).reshape(5000)

plt.plot(np.arange(5000),HC_data['HC'],label='HC')
# plt.plot(np.arange(5000),HC_data['HC1'])
# plt.plot(np.arange(5000),HC_data['HC2'])
plt.plot(np.arange(5000),SA_list,label='SA')
plt.plot(np.arange(5000),SA_linlist,label='SA linear')
plt.plot(np.arange(5000),SA_explist,label='SA exp')
plt.legend()
plt.show()

# %%
def ODE(data,t,alpha,beta,gamma,delta):
    """Return set of ODE's for given data and params."""

    # data should be array-like of prey and predator quantities respectively
    # params should be array-like of 4 params (alpha, beta, gamma, delta)
    x, y = data
    dxdt = alpha*x - beta*x*y
    dydt = delta*x*y - gamma*y
    return [dxdt,dydt]

df_params = pd.read_csv('Data/params-RMSE.csv',index_col=0)
fit_HC = integrate.odeint(ODE, data[0], t, args=tuple(df_params['HC125']))
fit_HC1 = integrate.odeint(ODE, data[0], t, args=tuple(df_params['HC_start1']))
fit_HC2 = integrate.odeint(ODE, data[0], t, args=tuple(df_params['HC_start2']))
fit_SA = integrate.odeint(ODE, data[0], t, args=tuple(df_params['SA025']))



fig,ax = plt.subplots(6,figsize=(10,30))
fit_list = [fit_HC,fit_HC1,fit_HC2,fit_SA]
for i in range(len(fit_list)):
    ax[i].scatter(t,data[:,0],label='x data')
    ax[i].scatter(t,data[:,1],label='y data')
    ax[i].plot(t,fit_list[i][:,0], label='x fit')
    ax[i].plot(t,fit_list[i][:,1], label='y fit')
ax[0].legend()

# %%
df_lessdata = pd.read_csv('Data/rndm-frac-RMSE.csv',index_col=0)
perc = np.arange(1,0.2,-0.1)
HC = df_lessdata['HC_mean']
SA = df_lessdata['SA_mean']

plt.plot(perc,HC)
plt.fill_between(perc, HC+df_lessdata['HC_std'], HC-df_lessdata['HC_std'], alpha=0.1)
plt.plot(perc,SA)
plt.fill_between(perc, SA+df_lessdata['SA_std'], SA-df_lessdata['SA_std'], alpha=0.1)
plt.xlim((1,0.3))
# Out:
# (1.0, 0.3)

# %%
temprange=(1,10**-3)
temp0 = temprange[0]
temp_end = temprange[1]
n_iter= 3000
alpha = (temp0/temp_end-1)/n_iter**2
rate = (temp_end / temp0) **(1/(n_iter - 1))
np.exp(-0.012938548355024171/(0.1))
temp = temp0/(1+alpha*np.arange(n_iter)**2)
temp = temp0*rate**np.arange(n_iter)
prob = np.exp(-0.4/temp)
prob[1]
# Out:
# 0.6697020258543822
